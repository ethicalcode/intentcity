# %%
import pandas as pd

# %%
demos = pd.read_excel('data/all_homeless_abs_demo.csv_homeless_abs_demo.csv')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-18-2ddb2537d5b0> in <module>()
# ----> 1 demos = pd.read_excel('data/all_homeless_abs_demo.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
demos
# Out:
#                                                           Unnamed: 0_level_0  \
#                                                           Unnamed: 0_level_1
# NaN                                                                      SA4
# Australia                                                                NaN
# NaN                                                                      NaN
# New South Wales                                                          NaN
# NaN                                                           Capital Region
# NaN                                                                      NaN
# NaN                                                                      NaN
# NaN                                                                      NaN
# NaN                                                                      NaN
# NaN                                                            Central Coast
# ...
