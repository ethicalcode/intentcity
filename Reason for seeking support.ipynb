# %%
import pandas as pd
# %matplotlib inline

# %%
frame = pd.read_csv('data/askizzy/Main reason (first reported).csv')

# %%
by_year = frame.groupby('Year').sum()

# %%
by_year.loc[2015].plot(kind='bar')
